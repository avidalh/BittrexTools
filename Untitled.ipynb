# %%
import pandas as pd
import matplotlib.pyplot as plt
import json

# %config InlineBackend.figure_format='retina'
# %matplotlib inline

# url to pick historical data:
# https://bittrex.com/Api/v2.0/pub/market/GetTicks?marketName=BTC-ZEC&tickInterval=oneMin&_=1499127220008

filename = './USDT-ZEC_thirtyMin.json'

# loads json data into dataframe, set datetime as table index
with open(filename) as data_file:
    data = json.load(data_file)
data = data['result']
df = pd.DataFrame.from_dict(data)
df = df.set_index(pd.DatetimeIndex(df['T']) )

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1912 entries, 2017-09-08 13:30:00 to 2017-10-18 13:00:00
# Data columns (total 7 columns):
# BV    1912 non-null float64
# C     1912 non-null float64
# H     1912 non-null float64
# L     1912 non-null float64
# O     1912 non-null float64
# T     1912 non-null object
# V     1912 non-null float64
# dtypes: float64(6), object(1)
# memory usage: 119.5+ KB

# %%
df.head()
# Out:
#                                 BV           C        H        L        O  \
# 2017-09-08 13:30:00  135035.270806  225.000000  241.245  222.200  241.245
# 2017-09-08 14:00:00  125363.056461  210.029999  225.000  204.260  225.000
# 2017-09-08 14:30:00   53075.474831  223.800000  229.059  210.000  210.125
# 2017-09-08 15:00:00  101409.491556  219.844000  223.800  214.303  223.800
# 2017-09-08 15:30:00   32339.919150  224.546000  224.546  215.001  216.400
#
#                                        T           V
# 2017-09-08 13:30:00  2017-09-08T13:30:00  587.259618
# 2017-09-08 14:00:00  2017-09-08T14:00:00  585.307072
# 2017-09-08 14:30:00  2017-09-08T14:30:00  241.803527
# 2017-09-08 15:00:00  2017-09-08T15:00:00  460.699544
# 2017-09-08 15:30:00  2017-09-08T15:30:00  146.829790

# %%
df.plot(y=['C'], figsize=(16,9), grid=True)
