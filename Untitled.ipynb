# %%
import pandas as pd
import matplotlib.pyplot as plt
import json

# %config InlineBackend.figure_format='retina'
# %matplotlib inline

filename = './1min_data.json'

# loads json data into dataframe, set datetime as table index
with open(filename) as data_file:
    data = json.load(data_file)
data = data['result']
df = pd.DataFrame.from_dict(data)
df = df.set_index(pd.DatetimeIndex(df['T']) )

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 12541 entries, 2017-10-07 10:32:00 to 2017-10-17 10:28:00
# Data columns (total 7 columns):
# BV    12541 non-null float64
# C     12541 non-null float64
# H     12541 non-null float64
# L     12541 non-null float64
# O     12541 non-null float64
# T     12541 non-null object
# V     12541 non-null float64
# dtypes: float64(6), object(1)
# memory usage: 783.8+ KB

# %%
df['O'].plot(figsize=(12,4), grid=True)
